# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### View The Data
# I will start by seeing what we got from our data collection. How many rows have location data and what does this data look like.

# %%
mydata = "tweets1018913.csv"
df = pd.read_csv(mydata)
df.head(5)
# Out:
#    Unnamed: 0                 t_id         s_name  \
# 0         0.0  1052370940128968705  brandycooklyn
# 1         1.0  1052370675632091136      Louroulai
# 2         2.0  1052370144180211719        _WayneJ
# 3         3.0  1052369947236724736   Imposter_Cat
# 4         4.0  1052369944506068992     isaidimhip
#
#                                               t_text             u_location  \
# 0  THINGS WRITERS LOVE:\n\n- Panel discussions.\n...   Melbourne, Australia
# 1  RT @nelsonlflores: Tips for avoiding imposter ...                    NaN
# 2  RT @nelsonlflores: Tips for avoiding imposter ...                     GA
# 3  RT @isaidimhip: Anyway........anybody else fee...  impostersyndrome.life
# 4  Anyway........anybody else feeling that impost...                    NaN
#
#                                            image_url               t_date
# 0  http://pbs.twimg.com/profile_images/1042972658...  2018-10-17 01:29:18
# 1  http://pbs.twimg.com/profile_images/2379147043...  2018-10-17 01:28:15
# 2  http://pbs.twimg.com/profile_images/1050602456...  2018-10-17 01:26:09
# 3  http://pbs.twimg.com/profile_images/1047849327...  2018-10-17 01:25:22
# 4  http://pbs.twimg.com/profile_images/1021102005...  2018-10-17 01:25:21

# %%
df.dtypes
# Out:
# Unnamed: 0    float64
# t_id           object
# s_name         object
# t_text         object
# u_location     object
# image_url      object
# t_date         object
# dtype: object

# %%
df.shape
# Out:
# (26819, 7)

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Unnamed: 0     286
# t_id             0
# s_name           0
# t_text           0
# u_location    4646
# image_url        0
# t_date           0
# dtype: int64

# %% [raw]
# We see that we have over 26K tweets and all but 4646 of them have some sort of location data. The field we will be cleaning is u_locations. So, lets take a look at the uniq values that are inside this field.

# %%
df['u_location'].value_counts(ascending=False).head(20)
# Out:
# impostersyndrome.life    4552
# London, England           387
# u_location                286
# London                    256
# Los Angeles, CA           220
# United States             178
# Chicago, IL               166
# Washington, DC            151
# Boston, MA                141
# New York, NY              140
# United Kingdom            138
# Houston, TX               124
# California, USA           117
# UK                        104
# Seattle, WA               100
# Atlanta, GA                99
# Brooklyn, NY               88
# San Francisco, CA          85
# Philadelphia, PA           83
# Portland, OR               81
# Name: u_location, dtype: int64

# %%
df['u_location'].value_counts(ascending=False).tail(20)
# Out:
# Lahti, Suomi                      1
# DC/Boston/New Haven               1
# Los                               1
# A noisy MDF                       1
# Soul searching✨                   1
# Beantown                          1
# dnd                               1
# ptx/frisco/Hunstvegas             1
# $C                                1
# NorCal                            1
# Staten Island, NY.                1
# Sunderland UK                     1
# Old Dominion University ‘21       1
# 661-415                           1
# Sheffield                         1
# IG: julia_victoriaa               1
# Retweets are not Endorsements     1
# Rockville, MD                     1
# Disbelief, USA                    1
# Bethlehem, PA                     1
# Name: u_location, dtype: int64

# %% [markdown]
# ## What are we looking for?
# Ok, some places are real and some are not. Looking at the data I am going to stick with locations in the USA and locations that have been picked via the drop-down menu on twitter. Here is what they look like:
# #### City, State:
# Maplewood, NJ
# #### State, County:
# New Jersey, USA
# #### Country:
# United States
#
# 1. Entries will have a single comma or be "United States"
# 2. Full city name with a state abbriviation
# 3. Full state name with a country abbriviation
# 4. Full country name
#
# #### What we want, is to convert it to one of the following:
#
# Maplewood, New Jersey, USA
#
# New Jersey, USA
#
# USA

# %% [markdown]
# ## Cleaning
# 1. Remove empty location rows
# 2. Convert NJ to New Jersey, USA
# 3. Convert United States to USA
# 4. Keep only fileds that have USA in them
# 5. Removing retweets

# %%
# mark if a retweet and then drop
df['get_rt'] = df['t_text'].str.startswith('RT')
df.drop(df[df['get_rt'] == True].index, inplace=True)
df.shape
# Out:
# (7795, 8)

# %% [markdown]
# That was a lot of retweets the number of original tweets is 7795. Next we drop all empty locations and take a look at our data again.

# %%
df.dropna(subset=['u_location'], how='all', inplace = True)

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Unnamed: 0    286
# t_id            0
# s_name          0
# t_text          0
# u_location      0
# image_url       0
# t_date          0
# get_rt          0
# dtype: int64

# %%
df.shape
# Out:
# (6561, 8)

# %% [markdown]
# We started with a little over 26k tweets and are down to around 7k. Now we will convert NJ to New Jersey, USA and United States to USA. I do this using a dictionary for all of the states.

# %%
us_state_abbrev = {
    'AL': 'Alabama, USA',
    'AK': 'Alaska, USA',
    'AZ': 'Arizona, USA',
    'AR': 'Arkansas, USA',
    'CA': 'California, USA',
    'CO': 'Colorado, USA',
    'CT': 'Connecticut, USA',
    'DE': 'Delaware, USA',
    'FL': 'Florida, USA',
    'GA': 'Georgia, USA',
    'HI': 'Hawaii, USA',
    'ID': 'Idaho, USA',
    'IL': 'Illinois, USA',
    'IN': 'Indiana, USA',
    'IA': 'Iowa, USA',
    'KS': 'Kansas, USA',
    'KY': 'Kentucky, USA',
    'LA': 'Louisiana, USA',
    'ME': 'Maine, USA',
    'MD': 'Maryland, USA',
    'MA': 'Massachusetts, USA',
    'MI': 'Michigan, USA',
    'MN': 'Minnesota, USA',
    'MS': 'Mississippi, USA',
    'MO': 'Missouri, USA',
    'MT': 'Montana, USA',
    'NE': 'Nebraska, USA',
    'NV': 'Nevada, USA',
    'NH': 'New Hampshire, USA',
    'NJ': 'New Jersey, USA',
    'NM': 'New Mexico, USA',
    'NY': 'New York, USA',
    'NC': 'North Carolina, USA',
    'ND': 'North Dakota, USA',
    'OH': 'Ohio, USA',
    'OK': 'Oklahoma, USA',
    'OR': 'Oregon, USA',
    'PA': 'Pennsylvania, USA',
    'RI': 'Rhode Island, USA',
    'SC': 'South Carolina, USA',
    'SD': 'South Dakota, USA',
    'TN': 'Tennessee, USA',
    'TX': 'Texas, USA',
    'UT': 'Utah, USA',
    'VT': 'Vermont, USA',
    'VA': 'Virginia, USA',
    'WA': 'Washington, USA',
    'WV': 'West Virginia, USA',
    'WI': 'Wisconsin, USA',
    'WY': 'Wyoming, USA',
    'United States': 'USA'
}

# %%
# Convert 2 letter abbrv. to State name, USA
df['u_location'] = df['u_location'].replace(us_state_abbrev, regex=True)

# %%
# mark all with the count of USA and grab those with only one.
usa_counts = df['u_location'].str.count('USA')
# usa_counts
df['with_usa'] = np.where((usa_counts == 1),df.u_location, "")

# %%
df['with_usa'].value_counts(ascending=False).tail(10)
# Out:
# Bayside, New York, USA                        1
# NOLouisiana, USA✈️DC                          1
# Knoxville, Tennessee, USA                     1
# Oregon, USA                                   1
# My Mind, Florida, USA                         1
# Columbus, Indiana, USA                        1
# Kansas, USA                                   1
# Windsor Hills, California, USA                1
# Beaufort South Carolina, USA | Oxford U.K.    1
# Davenport, Florida, USA                       1
# Name: with_usa, dtype: int64

# %%
df['with_usa'].value_counts(ascending=False).head(20)
# Out:
#                                   4346
# Los Angeles, California, USA       111
# New York, New York, USA             81
# Chicago, Illinois, USA              70
# USA                                 66
# California, USA                     63
# Oak Park, Illinois, USA             61
# Seattle, Washington, USA            61
# San Francisco, California, USA      51
# Illinois, USA                       46
# Brooklyn, New York, USA             42
# Louisville, Kentucky, USA           41
# New York, USA                       38
# Boston, Massachusetts, USA          34
# Davis, California, USA              34
# District of Columbia, USA           33
# Austin, Texas, USA                  32
# Portland, Oregon, USA               31
# Oakland, California, USA            31
# Houston, Texas, USA                 31
# Name: with_usa, dtype: int64

# %% [markdown]
# #### Evaluate
# This is much better but we are still getting some krust, I am going to see if I can clean this up a bit more by removing any entry that has a special char. or does not end in USA

# %%
# Must end with USA
end_usa = df['u_location'].str.endswith('USA')
df['with_usa'] = np.where((end_usa == True),df.with_usa, "")
#df['with_usa'].value_counts(ascending=False).tail(120)

# %%
# No junk in the location field
df['with_usa'] = df['with_usa'].str.replace('[^a-zA-Z\s,]', '')

# %%
# make sure all fields are populated
df.dropna(inplace = True)

# %%
df['usa_count'] = df['with_usa'].str.count('USA')
df.drop(df[df['usa_count'] == 0].index, inplace=True)

# %%
# we can only have up to two commas, drop rows with more
comma_counts = df['with_usa'].str.count(',')
df['with_comma'] = np.where((comma_counts <= 2),df.with_usa, "")
df.shape
# Out:
# (2134, 11)

# %% [markdown]
# This takes us down to 2134 tweets that have pretty clean location information.

# %% [markdown]
# #### Split into three different rows
# I split the location data into three rows with a split in reverse order. This orders the data with a left justify. I then strip each row of extra spaces and drop the column we do not need. Finally I write out the new csv file.

# %%
# split into three fields
df[['Country', 'State', 'City']] = df['with_comma'].apply(lambda x:pd.Series(x.split(",")[::-1]))

# %%
# strip extra spaces
df['Country'] = df['Country'].str.strip()
df['State'] = df['State'].str.strip()
df['City'] = df['City'].str.strip()

# %%
# drop unused columns
df.drop(['with_usa', 'usa_count', 'with_comma', 'get_rt'], axis=1)
# Out:
#        Unnamed: 0                 t_id           s_name  \
# 7             7.0  1052369469580820481       hayleydenb
# 16           16.0  1052367305726865408            molls
# 79           79.0  1052357068118740992    Hentai4Dinner
# 81           81.0  1052356563690840065        emilymias
# 91           91.0  1052354795632250881    DopeBlckQueen
# 102           1.0  1052352901648125957        kanavjain
# 108           7.0  1052352462844133377            gmksp
# 118          17.0  1052349532871188480        jimtoepel
# 151          50.0  1052345893200904197       _markryann
# 153          52.0  1052345782676975616      IamAleshiaP
# 166          65.0  1052341667456606209         mznewman
# 172          71.0  1052339756267229186    davidbrunelle
# 175          74.0  1052338650355261440        drewgrham
# 188          87.0  1052335423878569985     ScottGoyette
# 196          95.0  1052333909499944960    nelsonlflores
# 211           9.0  1052331246683115521    heybluewrites
# 217          15.0  1052330227874062337         siddante
# 224          22.0  1052329796124991488   AdamDLindstrom
# 248          46.0  1052325511068758016       SawakoSono
# 267          65.0  1052321750023692289        tinaatang
# 272          70.0  1052321336096374792        anna_boeg
# 294          92.0  1052316812153520128    musingvirtual
# 295          93.0  1052316404752572429           xnaunx
# 319          16.0  1052313748352905216     alexhareland
# 337          34.0  1052310999729139718  possiblehorizon
# 355          52.0  1052308459364978689    Alcrowldabest
# 361          58.0  1052308186366009344         RentPoet
# 364          61.0  1052307760614785024           chep2m
# 366          63.0  1052307684983222272   AmLitCritTwitt
# 382          79.0  1052305194883502080           chep2m
# ...           ...                  ...              ...
# 26537        20.0  1052709673978273792     OliviakUmana
# 26542        25.0  1052708514500673536  constancekassor
# 26544        27.0  1052708138330324993      JustinFlood
# 26551        34.0  1052705788458913792  AlexaEisenbarth
# 26577        60.0  1052698267568562176            urcym
# 26579        62.0  1052698153877684224           w9jds_
# 26584        67.0  1052697264966303744   adrianafitnall
# 26587        70.0  1052696694935224320      MsJohnson16
# 26589        72.0  1052695582442024964         TDHRehab
# 26593        76.0  1052693895585419264    jamesingramii
# 26601        84.0  1052692474898968576        dejbrown_
# 26614        97.0  1052689723494420480       GrubFellow
# 26615        98.0  1052689444472573952     serenalarkin
# 26616        99.0  1052689272900182022    katieboundary
# 26628        10.0  1052687067925307392           j_lnch
# 26675        57.0  1052671040755777538    AnnieRoonie13
# 26697        79.0  1052667871191490560           defjoy
# 26698        80.0  1052667869073412096      bdclendenin
# 26704        86.0  1052667629771608064       biaMedious
# 26707        89.0  1052667045060460548      HRay_Of_Sun
# 26735        16.0  1052659576133349377       typedoutco
# 26737        18.0  1052659091745562625  neener_baneener
# 26741        22.0  1052658233972801542     TeganTrovato
# 26746        27.0  1052657044724039687         Kcap1313
# 26748        29.0  1052656566313336833          bcjordo
# 26758        39.0  1052655395569889280  nickolysalmeida
# 26769        50.0  1052653395927023617       ladybotfly
# 26782        63.0  1052648501144891393      RNickGorton
# 26788        69.0  1052647590091780098          mhstein
# 26809        90.0  1052643019856330752          JBRylah
#
#                                                   t_text  \
# 7      True story. I had a dream last night that I wa...
# 16     @katieferg @kimberlylhudson If you're being st...
# 79     Does anybody else know what imposter syndrome ...
# 81     I had the privilege today to talk to  @MassArt...
# 91     this transition to graduate school has been on...
# 102    and @r2rothenberg talks to us about how he got...
# 108            Imposter syndrome https://t.co/evAj9wZC0z
# 118    @Hellchick Spoiler: It's imposter syndrome all...
# 151    #NationalBossDay \nI have the worst imposter s...
# 153    @CRWNmag @Travepreneur I dealt with Imposter S...
# 166    What's it called if you're just a bit unsure o...
# 172    @DotProto @Calendly Filed that away with the "...
# 175    @doilookwasted @AllspiceRose Sorry for calling...
# 188    Stoked! Probably breaking a few rules with thi...
# 196    Me: Let me tweet about how to avoid imposter s...
# 211    People complaining about DV Pit meanwhile I'm ...
# 217    Proud of Austin.  Honored to be his friend.  H...
# 224    Imposter syndrome?  Go check out @human_perisc...
# 248    About imposter syndrome and entrepreneurial an...
# 267    when ur whole life is the imposter syndrome :-...
# 272    My imposter syndrome has spilled over into the...
# 294    "All of them had stunted career growth. Non-tr...
# 295    Yeah! You too can be crying at the school of y...
# 319    I've been fighting some major imposter syndrom...
# 337    @AliaJoyH When the imposter syndrome strikes, ...
# 355    I’ll have my LCSW in a few months but imposter...
# 361    Imposter syndrome has been an ongoing theme, a...
# 364    1/3\n\nAbout Imposter Syndrome...\n\na) pretty...
# 366    @EmpyrealGradult Man “enough” is that thing we...
# 382    Hey, friends at Activate #Montreal: proud to r...
# ...                                                  ...
# 26537  @tephie_mm Girl, yes! It was killing me and pl...
# 26542  @matilda_jt @AcademicChatter It might not seem...
# 26544                    Imposter syndrome is the worst.
# 26551                      Imposter syndrome is terrible
# 26577                  I think I have imposter syndrome.
# 26579  Everyday I suffer from things like imposter sy...
# 26584  Two-Thirds Of Women In UK Suffer From #Imposte...
# 26587  Imposter syndrome tells you that people say ni...
# 26589  Get some #WednesdayWisdom with our latest epis...
# 26593  Some days I feel like I'm not even good enough...
# 26601  lately i have been feeling like i do not belon...
# 26614                     @mathimus55 Imposter Syndrome.
# 26615  When you read a literary deconstruction of the...
# 26616  I work best when I'm in a positive environment...
# 26628  @PatjBrennan It’s 3 layer chocolate mousse cak...
# 26675  @olive_huffman That’s Imposter Syndrome speaki...
# 26697  @jjamesfloyd Right? Particularly since I hung ...
# 26698  I can’t wait to be around a bunch of poets and...
# 26704  “The very act of being in the room means you b...
# 26707  Check out this upcoming webinar on imposter sy...
# 26735  Imposter syndrome is a real thing, y’all. Does...
# 26737  Imposter syndrome is kicking my ass rn and I’m...
# 26741  Having the Imposter Syndrome can lead to a lac...
# 26746  Great turnout for the #asfw event on beating i...
# 26748  We're sharing a peek behind the curtain on som...
# 26758  been feeling that imposter syndrome pretty har...
# 26769  New goals for before-2019:\n- You learned what...
# 26782  @ffolliet @EMSwami @darakass @feminemtweets @j...
# 26788  @roseperson I think it happens to 90% or more ...
# 26809  @alicialutes Hi, hello, hey. I think the indus...
#
#                                               u_location  \
# 7                             San Diego, California, USA
# 16                          Los Angeles, California, USA
# 79                            Springfield, Missouri, USA
# 81                            Boston, Massachusetts, USA
# 91                          Raleigh, North Carolina, USA
# 102                              New York, New York, USA
# 108                                  Tempe, Arizona, USA
# 118                             Redmond, Washington, USA
# 151                             Boncord, California, USA
# 153                           Saint Louis, Missouri, USA
# 166                            Milwaukee, Wisconsin, USA
# 172                             Seattle, Washington, USA
# 175                      Philadelphia, Pennsylvania, USA
# 188                                        Delaware, USA
# 196                      Philadelphia, Pennsylvania, USA
# 211                                    North Dakota, USA
# 217                             Baltimore, Maryland, USA
# 224                                      New Jersey, USA
# 248                       San Francisco, California, USA
# 267                                  UCSouth Dakota, USA
# 272    Occupied Anishinaabe land in Detroit, Michigan...
# 294                             Oakland, California, USA
# 295                          Hanover, New Hampshire, USA
# 319                             Oakland, California, USA
# 337                                Cincinnati, Ohio, USA
# 355                      Philadelphia, Pennsylvania, USA
# 361                         Los Angeles, California, USA
# 364                       San Francisco, California, USA
# 366                            Carbondale, Illinois, USA
# 382                       San Francisco, California, USA
# ...                                                  ...
# 26537                      Worcester, Massachusetts, USA
# 26542                           Appleton, Wisconsin, USA
# 26544                        West Babylon, New York, USA
# 26551                             Chicago, Illinois, USA
# 26577                                 Laredo, Texas, USA
# 26579                                      Illinois, USA
# 26584                                      New York, USA
# 26587                          Louisville, Kentucky, USA
# 26589                       Los Angeles, California, USA
# 26593                        Johnson City, New York, USA
# 26601                              Portland, Oregon, USA
# 26614                           Rochester, New York, USA
# 26615                            Madison, Wisconsin, USA
# 26616                     San Francisco, California, USA
# 26628                         San Diego, California, USA
# 26675                          District of Columbia, USA
# 26697                            Cortland, New York, USA
# 26698                            Brooklyn, New York, USA
# 26704                             Chicago, Illinois, USA
# 26707                           Birmingham, Alabama, USA
# 26735                            New York, New York, USA
# 26737                             Davis, California, USA
# 26741                                                USA
# 26746                                Columbus, Ohio, USA
# 26748                        Macungie, Pennsylvania, USA
# 26758                      Providence, Rhode Island, USA
# 26769                                      Illinois, USA
# 26782                             Davis, California, USA
# 26788                                         Maine, USA
# 26809                       Los Angeles, California, USA
#
#                                                image_url               t_date  \
# 7      http://pbs.twimg.com/profile_images/1047347755...  2018-10-17 01:23:28
# 16     http://pbs.twimg.com/profile_images/1046674961...  2018-10-17 01:14:52
# 79     http://pbs.twimg.com/profile_images/1033836023...  2018-10-17 00:34:11
# 81     http://pbs.twimg.com/profile_images/9375178224...  2018-10-17 00:32:11
# 91     http://pbs.twimg.com/profile_images/1040736565...  2018-10-17 00:25:09
# 102    http://pbs.twimg.com/profile_images/1038427834...  2018-10-17 00:17:38
# 108    http://pbs.twimg.com/profile_images/1050619495...  2018-10-17 00:15:53
# 118    http://pbs.twimg.com/profile_images/9004442737...  2018-10-17 00:04:15
# 151    http://pbs.twimg.com/profile_images/1040674494...  2018-10-16 23:49:47
# 153    http://pbs.twimg.com/profile_images/9349134392...  2018-10-16 23:49:20
# 166    http://pbs.twimg.com/profile_images/8761625011...  2018-10-16 23:32:59
# 172    http://pbs.twimg.com/profile_images/1052346506...  2018-10-16 23:25:24
# 175    http://pbs.twimg.com/profile_images/9050938323...  2018-10-16 23:21:00
# 188    http://pbs.twimg.com/profile_images/8960972016...  2018-10-16 23:08:11
# 196    http://pbs.twimg.com/profile_images/8603366000...  2018-10-16 23:02:10
# 211    http://pbs.twimg.com/profile_images/1013891630...  2018-10-16 22:51:35
# 217    http://pbs.twimg.com/profile_images/5861530768...  2018-10-16 22:47:32
# 224    http://pbs.twimg.com/profile_images/1004140071...  2018-10-16 22:45:49
# 248    http://pbs.twimg.com/profile_images/8986607404...  2018-10-16 22:28:47
# 267    http://pbs.twimg.com/profile_images/1024621049...  2018-10-16 22:13:51
# 272    http://pbs.twimg.com/profile_images/9802105351...  2018-10-16 22:12:12
# 294    http://pbs.twimg.com/profile_images/9930099746...  2018-10-16 21:54:13
# 295    http://pbs.twimg.com/profile_images/9322086748...  2018-10-16 21:52:36
# 319    http://pbs.twimg.com/profile_images/8712394753...  2018-10-16 21:42:03
# 337    http://pbs.twimg.com/profile_images/8324228690...  2018-10-16 21:31:07
# 355    http://pbs.twimg.com/profile_images/8424608314...  2018-10-16 21:21:02
# 361    http://pbs.twimg.com/profile_images/1051017967...  2018-10-16 21:19:57
# 364    http://pbs.twimg.com/profile_images/8639701117...  2018-10-16 21:18:15
# 366    http://pbs.twimg.com/profile_images/9135438390...  2018-10-16 21:17:57
# 382    http://pbs.twimg.com/profile_images/8639701117...  2018-10-16 21:08:04
# ...                                                  ...                  ...
# 26537  http://pbs.twimg.com/profile_images/1009515312...  2018-10-17 23:55:19
# 26542  http://pbs.twimg.com/profile_images/1043518014...  2018-10-17 23:50:42
# 26544  http://pbs.twimg.com/profile_images/1044759395...  2018-10-17 23:49:13
# 26551  http://pbs.twimg.com/profile_images/1051258516...  2018-10-17 23:39:52
# 26577  http://pbs.twimg.com/profile_images/1035268036...  2018-10-17 23:09:59
# 26579  http://pbs.twimg.com/profile_images/9311902216...  2018-10-17 23:09:32
# 26584  http://pbs.twimg.com/profile_images/9154336506...  2018-10-17 23:06:00
# 26587  http://pbs.twimg.com/profile_images/7121103471...  2018-10-17 23:03:44
# 26589  http://pbs.twimg.com/profile_images/5776137383...  2018-10-17 22:59:19
# 26593  http://pbs.twimg.com/profile_images/1037438092...  2018-10-17 22:52:37
# 26601  http://pbs.twimg.com/profile_images/9269274325...  2018-10-17 22:46:58
# 26614  http://pbs.twimg.com/profile_images/9572595916...  2018-10-17 22:36:02
# 26615  http://pbs.twimg.com/profile_images/9153297015...  2018-10-17 22:34:56
# 26616  http://pbs.twimg.com/profile_images/9950318842...  2018-10-17 22:34:15
# 26628  http://pbs.twimg.com/profile_images/9983203212...  2018-10-17 22:25:29
# 26675  http://pbs.twimg.com/profile_images/1047570886...  2018-10-17 21:21:48
# 26697  http://pbs.twimg.com/profile_images/2021264241...  2018-10-17 21:09:12
# 26698  http://pbs.twimg.com/profile_images/1004192123...  2018-10-17 21:09:12
# 26704  http://pbs.twimg.com/profile_images/8779101838...  2018-10-17 21:08:15
# 26707  http://pbs.twimg.com/profile_images/1009307114...  2018-10-17 21:05:55
# 26735  http://pbs.twimg.com/profile_images/1049705501...  2018-10-17 20:36:15
# 26737  http://pbs.twimg.com/profile_images/1025233710...  2018-10-17 20:34:19
# 26741  http://pbs.twimg.com/profile_images/9178285043...  2018-10-17 20:30:55
# 26746  http://pbs.twimg.com/profile_images/1019645034...  2018-10-17 20:26:11
# 26748  http://pbs.twimg.com/profile_images/8583063060...  2018-10-17 20:24:17
# 26758  http://pbs.twimg.com/profile_images/1048669475...  2018-10-17 20:19:38
# 26769  http://pbs.twimg.com/profile_images/9899529754...  2018-10-17 20:11:41
# 26782  http://pbs.twimg.com/profile_images/1005541664...  2018-10-17 19:52:14
# 26788  http://pbs.twimg.com/profile_images/9605653115...  2018-10-17 19:48:37
# 26809  http://pbs.twimg.com/profile_images/7747210527...  2018-10-17 19:30:27
#
#       Country                 State                                  City
# 7         USA            California                             San Diego
# 16        USA            California                           Los Angeles
# 79        USA              Missouri                           Springfield
# 81        USA         Massachusetts                                Boston
# 91        USA        North Carolina                               Raleigh
# 102       USA              New York                              New York
# 108       USA               Arizona                                 Tempe
# 118       USA            Washington                               Redmond
# 151       USA            California                               Boncord
# 153       USA              Missouri                           Saint Louis
# 166       USA             Wisconsin                             Milwaukee
# 172       USA            Washington                               Seattle
# 175       USA          Pennsylvania                          Philadelphia
# 188       USA              Delaware                                   NaN
# 196       USA          Pennsylvania                          Philadelphia
# 211       USA          North Dakota                                   NaN
# 217       USA              Maryland                             Baltimore
# 224       USA            New Jersey                                   NaN
# 248       USA            California                         San Francisco
# 267       USA        UCSouth Dakota                                   NaN
# 272       USA              Michigan  Occupied Anishinaabe land in Detroit
# 294       USA            California                               Oakland
# 295       USA         New Hampshire                               Hanover
# 319       USA            California                               Oakland
# 337       USA                  Ohio                            Cincinnati
# 355       USA          Pennsylvania                          Philadelphia
# 361       USA            California                           Los Angeles
# 364       USA            California                         San Francisco
# 366       USA              Illinois                            Carbondale
# 382       USA            California                         San Francisco
# ...       ...                   ...                                   ...
# 26537     USA         Massachusetts                             Worcester
# 26542     USA             Wisconsin                              Appleton
# 26544     USA              New York                          West Babylon
# 26551     USA              Illinois                               Chicago
# 26577     USA                 Texas                                Laredo
# 26579     USA              Illinois                                   NaN
# 26584     USA              New York                                   NaN
# 26587     USA              Kentucky                            Louisville
# 26589     USA            California                           Los Angeles
# 26593     USA              New York                          Johnson City
# 26601     USA                Oregon                              Portland
# 26614     USA              New York                             Rochester
# 26615     USA             Wisconsin                               Madison
# 26616     USA            California                         San Francisco
# 26628     USA            California                             San Diego
# 26675     USA  District of Columbia                                   NaN
# 26697     USA              New York                              Cortland
# 26698     USA              New York                              Brooklyn
# 26704     USA              Illinois                               Chicago
# 26707     USA               Alabama                            Birmingham
# 26735     USA              New York                              New York
# 26737     USA            California                                 Davis
# 26741     USA                   NaN                                   NaN
# 26746     USA                  Ohio                              Columbus
# 26748     USA          Pennsylvania                              Macungie
# 26758     USA          Rhode Island                            Providence
# 26769     USA              Illinois                                   NaN
# 26782     USA            California                                 Davis
# 26788     USA                 Maine                                   NaN
# 26809     USA            California                           Los Angeles
#
# [2134 rows x 10 columns]

# %%
df.shape
# Out:
# (2134, 14)

# %%
# write out my file of clean tweets
df.to_csv('tweets_clean_1018.csv')
